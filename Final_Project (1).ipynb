# %%
# Connect to drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# # # Get to the project directory
# %cd /content/gdrive/MyDrive/FinalProject
# # clone the AudioLDM training repository
# !git clone https://github.com/haoheliu/AudioLDM-training-finetuning.git;

# %cd /content/gdrive/MyDrive/FinalProject/AudioLDM-training_finetuning
# Out:
# /content/gdrive/MyDrive/FinalProject
# fatal: destination path 'AudioLDM-training-finetuning' already exists and is not an empty directory.
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/FinalProject/AudioLDM-training_finetuning'
# /content/gdrive/MyDrive/FinalProject

# %%
# %cd /content/gdrive/MyDrive
# !ls /content/gdrive/MyDrive/FinalProject
# Out:
# AudioLDM-training-finetuning

# %%
# %cd /content/gdrive/MyDrive/FinalProject/
# %cd /content/gdrive/MyDrive/FinalProject/AudioLDM
# !cp -r /content/gdrive/MyDrive/FinalProject/AudioLDM /content
# # import sys
# # sys.path.insert(0, "/content/gdrive/MyDrive/FinalProject/AudioLDM")
# %cd /content/AudioLDM

# %%
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 59.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 95.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 44.7 MB/s eta 0:00:00

# %%
# !pip install pytorch-lightning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 18.4 MB/s eta 0:00:00
# ...

# %%
# fixing the pad_center 1 argument instead of 2 ERROR
# !pip install librosa==0.9.2
# !pip install einops
# !pip install torchlibrosa==0.0.2
# !pip install ftfy
# !pip install braceexpand
# !pip install webdataset
# !pip install wget
# !pip install timm
# !pip install transformers==4.30.0
# !pip install wandb
# !pip install taming-transformers

# %%
# %cd /content/gdrive/MyDrive/FinalProject/AudioLDM-training-finetuning
# %run audioldm_train/train/latent_diffusion.py -c audioldm_train/config/2023_08_23_reproduce_audioldm/audioldm_original.yaml
# Out:
# /content/gdrive/MyDrive/FinalProject/AudioLDM-training-finetuning
# INFO:lightning_fabric.utilities.seed:Seed set to 0
# SEED EVERYTHING TO 0
# Add-ons: []
# Build dataset split train from ['audiocaps']
# Data size: 49502
# /content/gdrive/MyDrive/FinalProject/AudioLDM-training-finetuning/audioldm_train/utilities/audio/stft.py:42: FutureWarning: Pass size=1024 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   fft_window = pad_center(fft_window, filter_length)
# /content/gdrive/MyDrive/FinalProject/AudioLDM-training-finetuning/audioldm_train/utilities/audio/stft.py:145: FutureWarning: Pass sr=16000, n_fft=1024, n_mels=64, fmin=0, fmax=8000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_basis = librosa_mel_fn(
# ...
